# %%
################################################################
################## Importing libraries #########################

### General libraries
from datetime import datetime, timedelta # to work with dates
import os # to work with directories
import glob # to find files in directories
import dask.config # to work with dask configuration 

### Extensions for Notebook
import import_ipynb # to import ipynb files

### Data Manipulation Libraries
import xarray as xr # to read netcdf files
import numpy as np # to work with arrays
import pandas as pd # to work with dataframes
import netCDF4 as nc # to read netcdf files
from netCDF4 import Dataset # to read netcdf files
import pyinterp # for interpolation
from pyinterp import fill, Axis, TemporalAxis, Grid3D, Grid2D # for interpolation
import random # to generate random numbers

### Plotting Libraries
import matplotlib.pyplot as plt # to plot
import matplotlib # to set plot parameters
import matplotlib.dates as mdates # to work with dates in plots
import matplotlib.colors as mcolors # to set plot parameters
import matplotlib.ticker as mticker # to set plot parameters
from mpl_toolkits.mplot3d import Axes3D # for 3D plots
import cmocean # nice ocean colormaps
import ipympl # to allow interactive plots
from matplotlib.colors import LinearSegmentedColormap # to create custom colormaps
import matplotlib.patches as mpatches # to add patches to plots

#from matplotlib.gridspec import GridSpec # to create subplots
import matplotlib.gridspec as gridspec # to create subplots
import matplotlib.cm as cm  # Import colormap module
from mpl_toolkits.axes_grid1 import make_axes_locatable # Import module for creating colorbars
import matplotlib.cm as cm  # Import colormap module
from mpl_toolkits.axes_grid1 import make_axes_locatable # Import module for creating colorbars
import matplotlib.lines as mlines # to add lines to plots

### Geographic Libraries
import cartopy.crs as ccrs  # Import Cartopy coordinate reference system
import cartopy.feature as cfeature  # Import Cartopy feature for adding land, coastlines, etc.
import cartopy # for cartographic projections
import xesmf as xe # for regridding
import pyproj # for cartographic projections
from pyproj import Proj, Transformer, transform # for cartographic projections
from scipy.spatial import Delaunay # for Delaunay triangulation
#pd.set_option('display.max_rows', 20) # maximum number of rows to display

### Signal Processing Libraries
from scipy.fftpack import fft # to compute the FFT
import scipy.fftpack as fp # for fast fourier transforms
from scipy.signal import welch # to compute the power spectral density
import xrft # to compute the FFT in xarray
from scipy.interpolate import griddata # for data interpolation
from scipy.interpolate import RegularGridInterpolator # for data interpolation
from scipy.interpolate import LinearNDInterpolator # for data interpolation
from scipy import signal # for signal processing
from scipy.signal import find_peaks # for signal processing
from scipy.spatial import Delaunay # for Delaunay triangulation

# Convolution Operations
from astropy.convolution import Gaussian2DKernel, interpolate_replace_nans # for convolution operations

# Scientific Computing and Evaluation
import xskillscore # for model evaluation

# System and Performance Management
import sys # for system management
import gc # for garbage collection

# Parallel Computing
from dask import delayed, compute # for parallel computing
from joblib import Parallel # for parallel computing
from joblib import delayed #as jb_delayed # for parallel computing

# Some mathematical operations
from math import * # for mathematical operations

################################################################
######### To have interactive graphs in the notebook ###########

# this line must be adapted depending what you are using:

# jupyter notebook
#%matplotlib notebook 

# jupyter lab:
# %matplotlib widget

# for external window graphs:
#%matplotlib

# for non-interactive graphs:
#%matplotlib inline

#matplotlib ipympl
