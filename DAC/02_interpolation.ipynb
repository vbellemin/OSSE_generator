# %%
# Improve by ChatGPT & GitHub Copilot
# Running the requierements.ipynb
# %run /bettik/PROJECTS/pr-data-ocean/riverama/Notebooks/OSSE_generator/requierements.ipynb

# %%
# Define the preprocessor function
def preprocess(ds):
    # Extract date from 'dac' variable's attributes and convert to a pandas datetime object
    date_str = ds.dac.attrs['date']  # Adjust this if necessary to match your actual date attribute
    date = pd.to_datetime(date_str, format='%Y-%m-%d %H:%M:%S.%f UTC').replace(tzinfo=None)  # Parse datetime and remove timezone to avoid conflicts

    # Align with the 'time_counter' format from SSH
    # Assigning the parsed date as a new coordinate, here renamed to 'time_counter' to match your requirement
    ds = ds.expand_dims('time_counter').assign_coords(time_counter=[date])

    return ds

# Path to the files - adjust the wildcard as necessary to match your filenames
path = "/bettik/PROJECTS/pr-data-ocean/riverama/Datos/DAC_marco/dac_dif_*.nc"

# Use xarray to open and concatenate the dataset along the new 'time_counter' dimension
# This uses the preprocess function defined above for each file
dac = xr.open_mfdataset(path, preprocess=preprocess, combine='nested', concat_dim='time_counter')

# At this point, 'dac' should be a single dataset with all files concatenated along 'time_counter'
# and the time information properly aligned with your requirements.

# %%
# Save the dataset to a new NetCDF file
dac.to_netcdf("/bettik/PROJECTS/pr-data-ocean/riverama/Datos/DAC_limpio/dac.nc")

# %% [markdown]
# ## Crop to SSH domain

# %%
dac = xr.open_mfdataset("/bettik/PROJECTS/pr-data-ocean/riverama/Datos/DAC_limpio/dac.nc")

# %%
# Define the boundary coordinates for cropping
lon_min, lon_max = 159.23333740234375, 172.34999084472656
lat_min, lat_max = -28.803945541381836, -15.699763298034668

# Find the dataset's grid resolution for longitude and latitude if not already known
lon_res = np.abs(np.diff(dac['longitude'].values)).mean()
lat_res = np.abs(np.diff(dac['latitude'].values)).mean()

# Adjust the min/max coordinates to ensure inclusion of the nearest points outside the specified boundaries
# This example assumes the dataset's coordinates are increasing
lon_min_adj = lon_min - (lon_min % lon_res)
lon_max_adj = lon_max + (lon_res - (lon_max % lon_res)) % lon_res
lat_min_adj = lat_min - (lat_min % lat_res)
lat_max_adj = lat_max + (lat_res - (lat_max % lat_res)) % lat_res

# Now, crop the dataset using the adjusted coordinates
dac_cropped = dac.sel(
    longitude=slice(lon_min_adj, lon_max_adj),
    latitude=slice(lat_min_adj, lat_max_adj)
)

# %%
# Save the dataset to a new NetCDF file
dac_cropped.to_netcdf("/bettik/PROJECTS/pr-data-ocean/riverama/Datos/DAC_limpio/dac_cropped.nc")

# %% [markdown]
# ## Temporal interpolation

# %%
dac_cropped = xr.open_mfdataset("/bettik/PROJECTS/pr-data-ocean/riverama/Datos/DAC_limpio/dac_cropped.nc")

# %%
# To crop the dataset to the specified time range, we can use the .sel() method with the 'time' coordinate
new_time = pd.date_range(start='2014-01-01 00:30', end='2014-12-31 23:30', freq='1H')
new_time_np = new_time.values.astype('datetime64[ns]')
# The 'method' argument specifies the interpolation method to use
dac_cropped_1h = dac_cropped.interp(time_counter=new_time, method='cubic')

# %%
# Save the dataset to a new NetCDF file
dac_cropped_1h.to_netcdf("/bettik/PROJECTS/pr-data-ocean/riverama/Datos/DAC_limpio/dac_cropped_1h.nc")

# %% [markdown]
# ## Spatial interpolation

# %% [markdown]
# ### Step 1: Setting Up Dask Distributed Cluster

# %%
from dask.distributed import Client, LocalCluster
from dask import delayed, compute

# Configuration based on your resource allocation
n_nodes = 4
cores_per_node = 16
total_memory = 600  # GB
memory_per_node = total_memory / n_nodes  # Memory allocated per node

# Setting up the LocalCluster
# Note: Adjust memory_limit based on the actual usage pattern you observe for your tasks
cluster = LocalCluster(n_workers=n_nodes, 
                       threads_per_worker=cores_per_node, 
                       memory_limit=f'{memory_per_node}GB')

client = Client(cluster)

# Display the Dask dashboard link
print(f'Dask Dashboard: {client.dashboard_link}')
# Out:
# Dask Dashboard: http://127.0.0.1:8787/status

# %% [markdown]
# ### Step 2: Loading Data with Dask

# %%
dac_cropped_1h = xr.open_mfdataset("/bettik/PROJECTS/pr-data-ocean/riverama/Datos/DAC_limpio/dac_cropped_1h.nc", chunks={'time_counter': 100, 'latitude': 25, 'longitude': 25}).load()

# %%
SSH = xr.open_dataset("/bettik/PROJECTS/pr-data-ocean/riverama/Datos/CALEDO60/una_hora_enero.nc", chunks={'y': 50, 'x': 50}).load()

# %% [markdown]
# ### Step 3: Define the Interpolation Function

# %%
# Function to interpolate data from dac_cropped_1h to the SSH grid
def interpolate_to_ssh_grid(dac_data, dac_lat, dac_lon, ssh_nav_lat, ssh_nav_lon):
    # Flatten the SSH grid for the interpolation function
    target_points = np.vstack((ssh_nav_lon.flatten(), ssh_nav_lat.flatten())).T
    # Create source grid
    lon_grid, lat_grid = np.meshgrid(dac_lon, dac_lat)
    source_points = np.vstack((lon_grid.flatten(), lat_grid.flatten())).T
    values = dac_data.flatten()
    # Interpolate
    interpolated_values_flat = griddata(source_points, values, target_points, method='linear')
    return interpolated_values_flat.reshape(ssh_nav_lat.shape)

# %% [markdown]
# ### Step 4: Parallel Interpolation Across Time Steps

# %%
# Prepare the datasets
dac_lat = dac_cropped_1h.latitude.values
dac_lon = dac_cropped_1h.longitude.values
ssh_nav_lat = SSH.nav_lat.values
ssh_nav_lon = SSH.nav_lon.values

# %%
from scipy.interpolate import griddata
# Delayed interpolation for each time step
results = []
for t in range(len(dac_cropped_1h.time_counter)):
    dac_data = dac_cropped_1h.dac.isel(time_counter=t).values
    res = delayed(interpolate_to_ssh_grid)(dac_data, dac_lat, dac_lon, ssh_nav_lat, ssh_nav_lon)
    results.append(res)

# Compute all interpolations in parallel
interpolated_values = compute(*results)
# Out:
# /home/riverama/.conda/envs/env-stage/lib/python3.11/site-packages/distributed/client.py:3157: UserWarning: Sending large graph of size 208.66 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# 2024-03-22 11:21:52,666 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:35363' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'interpolate_to_ssh_grid-b21f4d01-f520-4c40-a96c-bda52a069221', 'interpolate_to_ssh_grid-3e648cbe-faea-49a3-a040-4cef892ccc55', 'interpolate_to_ssh_grid-1530c9a8-71a9-4b13-b357-bd5c42ffaa78', 'interpolate_to_ssh_grid-33abe434-9422-46d3-b0c3-7cce781d0d3d', 'interpolate_to_ssh_grid-39063c2a-a4c2-4a5a-b91e-ce6c412cc75e', 'interpolate_to_ssh_grid-7f3b8a1d-1d7a-4124-894e-f07c253e83c8', 'interpolate_to_ssh_grid-a89b5490-b191-4be5-b9b9-2a8298cf70cd', 'interpolate_to_ssh_grid-5255ccfd-de28-49d8-afd9-c0a23880ab40', 'interpolate_to_ssh_grid-2d687593-4b65-42ef-980d-db7d880d53dc', 'interpolate_to_ssh_grid-2f6c0746-e3c3-4ee3-a6f7-6d02c915450b', 'interpolate_to_ssh_grid-84f6ceab-10a2-4b8a-b27b-b27fee36145d', 'interpolate_to_ssh_grid-8bd39685-9468-4b17-bd31-127b8d74ba69', 'interpolate_to_ssh_grid-4c0c2f62-0a3d-4dc6-a23f-e45a447d0a8f', 'interpolate_to_ssh_grid-dac4932d-78ac-48c6-81da-43ca4836cb34', 'interpolate_to_ssh_grid-e748723f-ed9a-4187-9202-1df06b5047f7', 'interpolate_to_ssh_grid-88289555-53fa-47d8-91f0-b6a2d9d10827', 'interpolate_to_ssh_grid-94a92286-4796-4a95-8991-744dabb01525', 'interpolate_to_ssh_grid-cc1e37d9-ca0d-4e25-9d73-23eb2095ec5b', 'interpolate_to_ssh_grid-9ff48d80-1e98-477d-97df-6f61bc0b8ae7', 'interpolate_to_ssh_grid-114e4391-7b41-47cc-8023-1b1f829ef13d', 'interpolate_to_ssh_grid-1d1957c2-2096-471c-b4e9-07160c33d9b7', 'interpolate_to_ssh_grid-492b77c8-453d-4c4a-afec-7067857202e9', 'interpolate_to_ssh_grid-a39ea837-e5cd-4172-88cd-ba9069e67328', 'interpolate_to_ssh_grid-0f8fd6df-542f-493f-a594-788e1fa17b3f', 'interpolate_to_ssh_grid-7edbdbe4-a52d-48eb-a1c5-4d90701bcc14', 'interpolate_to_ssh_grid-6bba41b9-be4f-43b7-9d97-119ad494cb3b', 'interpolate_to_ssh_grid-648546a8-02ef-4868-ab6a-ecec89dbef35', 'interpolate_to_ssh_grid-f69f9699-b8f1-4109-877c-2589f3187c34', 'interpolate_to_ssh_grid-ebb9abd3-0ad9-4a8d-b009-04f3307afed9', 'interpolate_to_ssh_grid-93e619a4-340b-4826-9127-a71c81ff40f8', 'interpolate_to_ssh_grid-773daf61-12cb-4ecb-a2d5-12ce7ee1e9fb', 'interpolate_to_ssh_grid-f85d383b-c5ad-4b8e-8e48-1739e8ea0409', 'interpolate_to_ssh_grid-ce6866b6-894f-433f-8f37-20181e9eedda', 'interpolate_to_ssh_grid-3812bf75-112b-4518-be88-6f5d0ca82c06', 'interpolate_to_ssh_grid-2fb5aa20-50c3-455c-9897-8a8a65e8d66d', 'interpolate_to_ssh_grid-19ee0df7-3fbf-4ea0-af57-5b0221c0a1d8', 'interpolate_to_ssh_grid-7a18b694-23be-48a9-b6d0-9497d1a5618d', 'interpolate_to_ssh_grid-03fabecb-6d2c-4672-a51a-01c819a4e434', 'interpolate_to_ssh_grid-dd2b7043-40f5-4e9a-a1b8-4dd18349098c', 'interpolate_to_ssh_grid-197087dc-3a9b-4f2e-9a97-d393c5ab52cd', 'interpolate_to_ssh_grid-3ea31d03-7b9a-4330-bdaf-1bdfdf660599', 'interpolate_to_ssh_grid-0c4cd878-1a84-4aed-96c3-0c2088db8d9c', 'interpolate_to_ssh_grid-64625567-835b-4ed3-869c-a6c25c701bf1', 'interpolate_to_ssh_grid-1508e9b9-282c-48db-81eb-cda80ccab5db', 'interpolate_to_ssh_grid-1475af1c-ea5e-4b8b-ac55-8bc2494a8ac2', 'interpolate_to_ssh_grid-ad15fbfc-8ac7-421d-8e5b-cb1f127c158e', 'interpolate_to_ssh_grid-760b3edd-2a8d-4dff-986e-2adc31767613', 'interpolate_to_ssh_grid-6208b43e-5865-4b9d-9268-65195c2093f4', 'interpolate_to_ssh_grid-c8e89106-c2e3-4eb7-8af4-148ade1f1e63', 'interpolate_to_ssh_grid-0f027fad-091b-48b5-844d-3410c04e884e', 'interpolate_to_ssh_grid-05f6b675-f0a8-47ff-a635-1b124c42c4dc', 'interpolate_to_ssh_grid-8c267c4f-0141-4bf6-b72d-a412f8d596b7', 'interpolate_to_ssh_grid-d554b133-ff4d-4f53-9c0e-fd5788502ae5', 'interpolate_to_ssh_grid-92f599d0-36c4-4a40-b21f-b14ffb036453', 'interpolate_to_ssh_grid-b85580a8-de82-4d12-8d20-18cd636e7cc9', 'interpolate_to_ssh_grid-459a280c-ce16-4536-a2a9-d2ca90f9c2ea', 'interpolate_to_ssh_grid-416ab56f-428a-4038-a3d2-7a3659d4c631', 'interpolate_to_ssh_grid-f3483a6c-44ee-4e19-8759-ecfb684f15fc', 'interpolate_to_ssh_grid-02854490-ac0a-4f90-9d62-0ad278f4ee7d', 'interpolate_to_ssh_grid-79b36611- ...
# 2024-03-22 11:21:52,900 - distributed.nanny - WARNING - Restarting worker
# 2024-03-22 11:22:12,920 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:44797' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'interpolate_to_ssh_grid-aa61eccb-a5ed-448c-a56a-f483eb85242f', 'interpolate_to_ssh_grid-b21f4d01-f520-4c40-a96c-bda52a069221', 'interpolate_to_ssh_grid-c0ff0491-9c80-40c0-8e23-4df0a809c1df', 'interpolate_to_ssh_grid-719a5c9c-e768-4716-aad4-9a5ffe57ee13', 'interpolate_to_ssh_grid-077b45e0-33f5-4568-b142-253815d8d9d3', 'interpolate_to_ssh_grid-b3d17863-6de9-417e-887e-491d4beee4ec', 'interpolate_to_ssh_grid-026f098c-d0cc-43a6-b9ed-28335e2e31ae', 'interpolate_to_ssh_grid-2f6c0746-e3c3-4ee3-a6f7-6d02c915450b', 'interpolate_to_ssh_grid-a561cd90-40b8-4781-af87-36c338000a6c', 'interpolate_to_ssh_grid-b5146ecb-5376-41a8-983f-c8fdbc6915d3', 'interpolate_to_ssh_grid-d565c7cb-9816-421e-aefd-b64f190e081e', 'interpolate_to_ssh_grid-8ecb5486-0630-4883-a8f0-1925024d84cc', 'interpolate_to_ssh_grid-84f6ceab-10a2-4b8a-b27b-b27fee36145d', 'interpolate_to_ssh_grid-4c0c2f62-0a3d-4dc6-a23f-e45a447d0a8f', 'interpolate_to_ssh_grid-74034410-38b7-46fc-8898-7954b87b8d1f', 'interpolate_to_ssh_grid-3020ddd8-458f-4c85-9910-21ddc261f76d', 'interpolate_to_ssh_grid-9d99504f-ae41-4360-b253-2ff2c7aee439', 'interpolate_to_ssh_grid-fed95c6f-8e8f-4bfa-8e63-55f918a46d88', 'interpolate_to_ssh_grid-af1f29f0-6305-4a0b-bfc4-4176ad826801', 'interpolate_to_ssh_grid-d283e3f2-b143-46e1-bf36-0436316a6a5e', 'interpolate_to_ssh_grid-114e4391-7b41-47cc-8023-1b1f829ef13d', 'interpolate_to_ssh_grid-7d15403a-c66c-4689-a0be-46dc842ccf85', 'interpolate_to_ssh_grid-be68b598-54e7-4295-adb9-c65c44b462af', 'interpolate_to_ssh_grid-492b77c8-453d-4c4a-afec-7067857202e9', 'interpolate_to_ssh_grid-a39ea837-e5cd-4172-88cd-ba9069e67328', 'interpolate_to_ssh_grid-6f998943-ef6c-4c86-b7b6-85c0673781bc', 'interpolate_to_ssh_grid-e5ae21a5-0a44-4939-8851-4051b6623ee6', 'interpolate_to_ssh_grid-1c158390-753a-4b23-ba57-e7fe491554b0', 'interpolate_to_ssh_grid-3d0c7d41-dd02-40e8-abb6-1bf671bd9270', 'interpolate_to_ssh_grid-158fdb0e-7dd5-49e3-a6bc-8823f940e27e', 'interpolate_to_ssh_grid-84a3bbc8-e7ef-480c-be62-cc9e1703172e', 'interpolate_to_ssh_grid-0d1e7390-a297-4a9f-b476-e7374c9e8424', 'interpolate_to_ssh_grid-a3c9cf38-b3b3-4ad9-b68e-73f0851774c1', 'interpolate_to_ssh_grid-8fbf2955-9af9-4988-9859-028bfd21b584', 'interpolate_to_ssh_grid-2db56f3a-ccdd-4891-ba59-f469a1008fba', 'interpolate_to_ssh_grid-be90b4c0-19e5-4d7b-96de-5ae790055351', 'interpolate_to_ssh_grid-77607f84-1f1e-49ad-9f65-f551522a25f0', 'interpolate_to_ssh_grid-d18928ae-f90a-4a0d-83fa-87e1e7d19114', 'interpolate_to_ssh_grid-93e619a4-340b-4826-9127-a71c81ff40f8', 'interpolate_to_ssh_grid-9b99907a-5f0f-46a0-a3c6-77b25fbe0384', 'interpolate_to_ssh_grid-773daf61-12cb-4ecb-a2d5-12ce7ee1e9fb', 'interpolate_to_ssh_grid-b581b476-12d3-45a0-abaf-497272c04f7b', 'interpolate_to_ssh_grid-f85d383b-c5ad-4b8e-8e48-1739e8ea0409', 'interpolate_to_ssh_grid-ce6866b6-894f-433f-8f37-20181e9eedda', 'interpolate_to_ssh_grid-a7ffbcf2-6984-4d0e-8dde-db3349e5a2b4', 'interpolate_to_ssh_grid-3812bf75-112b-4518-be88-6f5d0ca82c06', 'interpolate_to_ssh_grid-ce97182b-bec5-408c-b9a9-77c3ffe20a80', 'interpolate_to_ssh_grid-19ee0df7-3fbf-4ea0-af57-5b0221c0a1d8', 'interpolate_to_ssh_grid-7a18b694-23be-48a9-b6d0-9497d1a5618d', 'interpolate_to_ssh_grid-d38455ce-5312-45e0-aef8-93c0b9bdb157', 'interpolate_to_ssh_grid-b2b57717-d719-4f80-aced-5c7fa64deb9d', 'interpolate_to_ssh_grid-6cbd063c-fd98-4485-b4c9-819c9b5b243a', 'interpolate_to_ssh_grid-5eeb33c8-50d3-47d2-b5ab-0fef5ccec04f', 'interpolate_to_ssh_grid-70c95099-f4d0-4cb2-8a56-3f11f2fdbb25', 'interpolate_to_ssh_grid-90051ad3-7be4-4113-bcdf-ced941e58741', 'interpolate_to_ssh_grid-369e76d6-b859-4ee6-a3d3-2f7965e97818', 'interpolate_to_ssh_grid-dd2b7043-40f5-4e9a-a1b8-4dd18349098c', 'interpolate_to_ssh_grid-dec588ce-f3da-43a2-8de3-decf72b326ce', 'interpolate_to_ssh_grid-a5427fb8-3003-492f-85c6-83df56ec1905', 'interpolate_to_ssh_grid-afb26912- ...
# 2024-03-22 11:22:13,139 - distributed.nanny - WARNING - Restarting worker
# 2024-03-22 11:23:11,812 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:42413' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'interpolate_to_ssh_grid-aa61eccb-a5ed-448c-a56a-f483eb85242f', 'interpolate_to_ssh_grid-5dcc4c67-6a09-4cf1-8379-3d7773624639', 'interpolate_to_ssh_grid-3e648cbe-faea-49a3-a040-4cef892ccc55', 'interpolate_to_ssh_grid-1530c9a8-71a9-4b13-b357-bd5c42ffaa78', 'interpolate_to_ssh_grid-6346ddcd-aa34-4337-9592-4e304a23c697', 'interpolate_to_ssh_grid-33abe434-9422-46d3-b0c3-7cce781d0d3d', 'interpolate_to_ssh_grid-c0ff0491-9c80-40c0-8e23-4df0a809c1df', 'interpolate_to_ssh_grid-a89b5490-b191-4be5-b9b9-2a8298cf70cd', 'interpolate_to_ssh_grid-719a5c9c-e768-4716-aad4-9a5ffe57ee13', 'interpolate_to_ssh_grid-5dea8138-bcc7-495b-a2e8-3ee41ccf88ab', 'interpolate_to_ssh_grid-2e90be42-faa4-4979-b23b-1d06dd8b31fd', 'interpolate_to_ssh_grid-3abf31ff-2d0e-4f6a-82a8-41999fb5518a', 'interpolate_to_ssh_grid-b3d17863-6de9-417e-887e-491d4beee4ec', 'interpolate_to_ssh_grid-2d687593-4b65-42ef-980d-db7d880d53dc', 'interpolate_to_ssh_grid-e31bdf26-2fc5-451b-8846-1699a1ce931f', 'interpolate_to_ssh_grid-2f6c0746-e3c3-4ee3-a6f7-6d02c915450b', 'interpolate_to_ssh_grid-026f098c-d0cc-43a6-b9ed-28335e2e31ae', 'interpolate_to_ssh_grid-a561cd90-40b8-4781-af87-36c338000a6c', 'interpolate_to_ssh_grid-b5146ecb-5376-41a8-983f-c8fdbc6915d3', 'interpolate_to_ssh_grid-8ecb5486-0630-4883-a8f0-1925024d84cc', 'interpolate_to_ssh_grid-8bd39685-9468-4b17-bd31-127b8d74ba69', 'interpolate_to_ssh_grid-53b51b66-cf77-4838-b80f-4d3da6bab503', 'interpolate_to_ssh_grid-4c0c2f62-0a3d-4dc6-a23f-e45a447d0a8f', 'interpolate_to_ssh_grid-74034410-38b7-46fc-8898-7954b87b8d1f', 'interpolate_to_ssh_grid-8aad92a6-0ef4-45df-9ab8-13fdabc536a1', 'interpolate_to_ssh_grid-cc292bd0-46f5-4580-ab83-f841cf7784ff', 'interpolate_to_ssh_grid-378018d7-cf73-45dd-9652-e28702d97429', 'interpolate_to_ssh_grid-57f62d7d-9925-4f9b-9675-31ba58a20041', 'interpolate_to_ssh_grid-16ad246f-f9f4-45be-8827-f7439227f239', 'interpolate_to_ssh_grid-b7e8034f-06fc-4302-a3d9-54efec9a4396', 'interpolate_to_ssh_grid-dac4932d-78ac-48c6-81da-43ca4836cb34', 'interpolate_to_ssh_grid-3020ddd8-458f-4c85-9910-21ddc261f76d', 'interpolate_to_ssh_grid-e748723f-ed9a-4187-9202-1df06b5047f7', 'interpolate_to_ssh_grid-fed95c6f-8e8f-4bfa-8e63-55f918a46d88', 'interpolate_to_ssh_grid-a3741dae-1875-4ac7-8c6b-6134f9b518a8', 'interpolate_to_ssh_grid-af1f29f0-6305-4a0b-bfc4-4176ad826801', 'interpolate_to_ssh_grid-7e3efadd-1c3e-4ea8-bc83-1be785fd5bb2', 'interpolate_to_ssh_grid-22826127-cb3e-4eff-bca5-48b36a1ca7b5', 'interpolate_to_ssh_grid-01569f67-c439-46a7-93b1-b4e4c70bb952', 'interpolate_to_ssh_grid-cc1e37d9-ca0d-4e25-9d73-23eb2095ec5b', 'interpolate_to_ssh_grid-9ff48d80-1e98-477d-97df-6f61bc0b8ae7', 'interpolate_to_ssh_grid-114e4391-7b41-47cc-8023-1b1f829ef13d', 'interpolate_to_ssh_grid-d283e3f2-b143-46e1-bf36-0436316a6a5e', 'interpolate_to_ssh_grid-1d1957c2-2096-471c-b4e9-07160c33d9b7', 'interpolate_to_ssh_grid-d5419601-786a-466f-a7f7-a2b386f71bb3', 'interpolate_to_ssh_grid-be68b598-54e7-4295-adb9-c65c44b462af', 'interpolate_to_ssh_grid-700e2439-c1d0-40da-be8f-68d1d52ef0e0', 'interpolate_to_ssh_grid-e5ae21a5-0a44-4939-8851-4051b6623ee6', 'interpolate_to_ssh_grid-6f998943-ef6c-4c86-b7b6-85c0673781bc', 'interpolate_to_ssh_grid-333bc81e-745c-4c75-a8da-bbea667e911b', 'interpolate_to_ssh_grid-84a3bbc8-e7ef-480c-be62-cc9e1703172e', 'interpolate_to_ssh_grid-648546a8-02ef-4868-ab6a-ecec89dbef35', 'interpolate_to_ssh_grid-2db56f3a-ccdd-4891-ba59-f469a1008fba', 'interpolate_to_ssh_grid-f69f9699-b8f1-4109-877c-2589f3187c34', 'interpolate_to_ssh_grid-f4139650-6bc9-4d86-9ee9-e1e25246cbfe', 'interpolate_to_ssh_grid-bf7b7958-4590-4a8d-98a7-9ca57e59de82', 'interpolate_to_ssh_grid-b4e0f565-c2b3-4d84-b345-cfd7f13c163b', 'interpolate_to_ssh_grid-d18928ae-f90a-4a0d-83fa-87e1e7d19114', 'interpolate_to_ssh_grid-ebb9abd3-0ad9-4a8d-b009-04f3307afed9', 'interpolate_to_ssh_grid-93e619a4- ...
# 2024-03-22 11:23:12,004 - distributed.nanny - WARNING - Restarting worker
# 2024-03-22 11:23:46,088 - distributed.scheduler - WARNING - Removing worker 'tcp://127.0.0.1:32793' caused the cluster to lose already computed task(s), which will be recomputed elsewhere: {'interpolate_to_ssh_grid-aa61eccb-a5ed-448c-a56a-f483eb85242f', 'interpolate_to_ssh_grid-60a3f6dd-5bbb-4492-ab4a-2c37b2482661', 'interpolate_to_ssh_grid-983f27ec-0065-444b-970d-238616c19cd0', 'interpolate_to_ssh_grid-cc292bd0-46f5-4580-ab83-f841cf7784ff', 'interpolate_to_ssh_grid-1ab52780-1a0b-4725-b339-0c2d71d51c91', 'interpolate_to_ssh_grid-dac4932d-78ac-48c6-81da-43ca4836cb34', 'interpolate_to_ssh_grid-d283e3f2-b143-46e1-bf36-0436316a6a5e', 'interpolate_to_ssh_grid-cc1e37d9-ca0d-4e25-9d73-23eb2095ec5b', 'interpolate_to_ssh_grid-1c158390-753a-4b23-ba57-e7fe491554b0', 'interpolate_to_ssh_grid-8fbf2955-9af9-4988-9859-028bfd21b584', 'interpolate_to_ssh_grid-faf833a3-3125-4c5c-bd14-aa66f1737237', 'interpolate_to_ssh_grid-bf7b7958-4590-4a8d-98a7-9ca57e59de82', 'interpolate_to_ssh_grid-3d7421f9-acb3-4d32-b5a2-f3401d5b711c', 'interpolate_to_ssh_grid-a52dfa59-965e-4d03-8d62-8f167765b316', 'interpolate_to_ssh_grid-ce97182b-bec5-408c-b9a9-77c3ffe20a80', 'interpolate_to_ssh_grid-a0f795dc-c139-41ca-aa19-4abd94023c77', 'interpolate_to_ssh_grid-dd2b7043-40f5-4e9a-a1b8-4dd18349098c', 'interpolate_to_ssh_grid-197087dc-3a9b-4f2e-9a97-d393c5ab52cd', 'interpolate_to_ssh_grid-dec588ce-f3da-43a2-8de3-decf72b326ce', 'interpolate_to_ssh_grid-a5427fb8-3003-492f-85c6-83df56ec1905', 'interpolate_to_ssh_grid-1508e9b9-282c-48db-81eb-cda80ccab5db', 'interpolate_to_ssh_grid-c0bb7624-5369-4391-ae06-b924466bd173', 'interpolate_to_ssh_grid-ad15fbfc-8ac7-421d-8e5b-cb1f127c158e', 'interpolate_to_ssh_grid-c8e89106-c2e3-4eb7-8af4-148ade1f1e63', 'interpolate_to_ssh_grid-d0354cb1-63fd-4169-b9fb-ada7e0549c49', 'interpolate_to_ssh_grid-df4ce2db-9c60-49bf-97d9-f57ef9c8842f', 'interpolate_to_ssh_grid-ee3c357a-f5c7-4b05-8f32-5bc1f3f7a49f', 'interpolate_to_ssh_grid-459a280c-ce16-4536-a2a9-d2ca90f9c2ea', 'interpolate_to_ssh_grid-10770c65-aa33-4180-b66d-7d3f503a5ba7', 'interpolate_to_ssh_grid-b3619a60-e011-448d-b28b-c4d0ae3ce917', 'interpolate_to_ssh_grid-79b36611-749d-4750-84dd-a64ef58f37f5', 'interpolate_to_ssh_grid-591555a6-132b-4dfd-b1fe-7bdd06e6dcd9', 'interpolate_to_ssh_grid-ccb77746-7578-4a19-a604-ca1e5d74bf8e', 'interpolate_to_ssh_grid-38695bfc-aeca-446d-bd00-b30c05877b90', 'interpolate_to_ssh_grid-d95f371d-a1e7-413f-88f9-e455c5a4762e', 'interpolate_to_ssh_grid-6ba4d8ba-15a6-4377-b380-fbf7c29dfb9c', 'interpolate_to_ssh_grid-90bb8f25-5fee-430e-8e5f-ef58ea1a740f', 'interpolate_to_ssh_grid-e797d54f-4455-41c8-935d-5b295f3f0e83', 'interpolate_to_ssh_grid-5542e278-13ac-4c23-955d-e373fccc3b47', 'interpolate_to_ssh_grid-8b9d7fcb-8adc-4118-816e-3432746865b9', 'interpolate_to_ssh_grid-5a85e943-987b-45c0-bdcb-99b41cfa71b0', 'interpolate_to_ssh_grid-bbfb35c7-3204-429c-824a-318399baadeb', 'interpolate_to_ssh_grid-571f8511-bcbe-44eb-8fd1-98b479b1415c', 'interpolate_to_ssh_grid-31e8a8cd-bcff-4654-8220-e6d8d5ae0847', 'interpolate_to_ssh_grid-286adc87-93b0-4387-9381-8036c04a4de1', 'interpolate_to_ssh_grid-484c3587-fe74-43c2-9789-bce69007b8af', 'interpolate_to_ssh_grid-ac029536-ba60-4825-938b-00aaaa335e3d', 'interpolate_to_ssh_grid-c196c9ba-80e3-4a85-b7b6-e117bd487727', 'interpolate_to_ssh_grid-ad1d46e0-90b6-4374-89be-20c0e2f404bb', 'interpolate_to_ssh_grid-01c93ef4-56d2-4fad-a772-c6ca942266be', 'interpolate_to_ssh_grid-fa7036ac-4417-49f2-9143-36ce62280c3d', 'interpolate_to_ssh_grid-765bdf31-ac08-467d-87be-18410bc53bd1', 'interpolate_to_ssh_grid-b34397cb-ef5c-4fbd-99c5-545e973ef51a', 'interpolate_to_ssh_grid-78131fb4-2c18-459e-87fa-8f583f8326f8', 'interpolate_to_ssh_grid-65ba7910-82b9-42ed-b019-8775fa378967', 'interpolate_to_ssh_grid-ff764fcb-b12a-4665-91db-67b463844683', 'interpolate_to_ssh_grid-982f14d6-6fe9-46c3-9d01-8f0cba9e46bd', 'interpolate_to_ssh_grid-344907df-c6a3-4b12-b188-240e75501f87', 'interpolate_to_ssh_grid-aa93a628-d8e9-46f9-9e07-8091a6cba4c3', 'interpolate_to_ssh_grid-9478a0a8- ...
# 2024-03-22 11:23:46,755 - distributed.scheduler - ERROR - Couldn't gather keys: {'interpolate_to_ssh_grid-aa61eccb-a5ed-448c-a56a-f483eb85242f': 'queued', 'interpolate_to_ssh_grid-8aad92a6-0ef4-45df-9ab8-13fdabc536a1': 'queued', 'interpolate_to_ssh_grid-7e3efadd-1c3e-4ea8-bc83-1be785fd5bb2': 'queued', 'interpolate_to_ssh_grid-01569f67-c439-46a7-93b1-b4e4c70bb952': 'queued', 'interpolate_to_ssh_grid-6f998943-ef6c-4c86-b7b6-85c0673781bc': 'queued', 'interpolate_to_ssh_grid-333bc81e-745c-4c75-a8da-bbea667e911b': 'queued', 'interpolate_to_ssh_grid-93e619a4-340b-4826-9127-a71c81ff40f8': 'queued', 'interpolate_to_ssh_grid-6197ddf6-05ac-4ea8-baff-36fc5e73e7e4': 'queued', 'interpolate_to_ssh_grid-9b99907a-5f0f-46a0-a3c6-77b25fbe0384': 'queued', 'interpolate_to_ssh_grid-a0f795dc-c139-41ca-aa19-4abd94023c77': 'queued', 'interpolate_to_ssh_grid-0c4cd878-1a84-4aed-96c3-0c2088db8d9c': 'queued', 'interpolate_to_ssh_grid-20e35c2e-7cba-4a45-ae4d-763191bcf86e': 'queued', 'interpolate_to_ssh_grid-6ee631f7-4402-411b-9755-78a942b885d8': 'queued', 'interpolate_to_ssh_grid-19d81096-7cfa-4945-abb3-fef8d06045b3': 'queued', 'interpolate_to_ssh_grid-64625567-835b-4ed3-869c-a6c25c701bf1': 'queued', 'interpolate_to_ssh_grid-ad15fbfc-8ac7-421d-8e5b-cb1f127c158e': 'queued', 'interpolate_to_ssh_grid-8b1c0288-1b0e-41ee-a488-139ae9049d77': 'queued', 'interpolate_to_ssh_grid-43930738-7069-42ef-94e9-d28daed40255': 'queued', 'interpolate_to_ssh_grid-60ec7b33-dada-4329-be79-e2496759d880': 'queued', 'interpolate_to_ssh_grid-416ab56f-428a-4038-a3d2-7a3659d4c631': 'queued', 'interpolate_to_ssh_grid-b3619a60-e011-448d-b28b-c4d0ae3ce917': 'queued', 'interpolate_to_ssh_grid-3088da0d-d07d-42aa-823c-81bd2aacdd10': 'queued', 'interpolate_to_ssh_grid-2eb9fcc4-2164-4b31-80fb-83104fac5676': 'queued', 'interpolate_to_ssh_grid-259fea07-730c-4385-b4df-56733560d5b8': 'queued', 'interpolate_to_ssh_grid-0a1df719-635c-4e5c-ae4d-38dde1844270': 'queued', 'interpolate_to_ssh_grid-66938d89-f449-4e6c-a9de-aa6a669473b3': 'queued', 'interpolate_to_ssh_grid-98a88852-5fa9-4da2-abe3-a2ca2421722b': 'queued', 'interpolate_to_ssh_grid-986309df-2ab4-427d-94b8-db1869e78154': 'queued', 'interpolate_to_ssh_grid-27c47bcd-3f1a-4fb0-9333-c157837eb06c': 'queued', 'interpolate_to_ssh_grid-327ac9c9-c644-4df8-bf96-b1fbe0dfc807': 'queued', 'interpolate_to_ssh_grid-11a82c8d-a417-4bb0-bd9a-713cb96f563d': 'queued', 'interpolate_to_ssh_grid-2e06285a-7a36-4322-a9a5-b8d0f9c0723e': 'queued', 'interpolate_to_ssh_grid-ad1d46e0-90b6-4374-89be-20c0e2f404bb': 'queued', 'interpolate_to_ssh_grid-07e9223a-fef3-410d-b9f4-c6d252bbacf5': 'queued', 'interpolate_to_ssh_grid-8869ec7f-3d4e-48f5-9279-50e116831672': 'queued', 'interpolate_to_ssh_grid-b34397cb-ef5c-4fbd-99c5-545e973ef51a': 'queued', 'interpolate_to_ssh_grid-22e28576-0498-42a6-b207-7a3945be6525': 'queued', 'interpolate_to_ssh_grid-aa93a628-d8e9-46f9-9e07-8091a6cba4c3': 'queued', 'interpolate_to_ssh_grid-5c69b2fe-82b1-4ed2-bdcc-c65fac8149b8': 'queued', 'interpolate_to_ssh_grid-350dc748-16d4-482f-b7db-1eda7d9851ac': 'queued', 'interpolate_to_ssh_grid-8dc788ae-3f9f-429e-bea6-681e17b21a31': 'queued', 'interpolate_to_ssh_grid-355b7152-4f40-4474-8547-418b628d3a45': 'queued', 'interpolate_to_ssh_grid-75599d35-f2c2-45fe-828b-a8349fa85503': 'queued', 'interpolate_to_ssh_grid-a1fcd8b8-64c6-4976-ba04-abac49adc76a': 'queued', 'interpolate_to_ssh_grid-a97dee29-8de9-48cd-abe4-7b98c07d955a': 'queued', 'interpolate_to_ssh_grid-147e5350-2b12-4bec-838c-752f83502c66': 'queued', 'interpolate_to_ssh_grid-808d1a83-464a-43b9-8e20-a672db616db4': 'queued', 'interpolate_to_ssh_grid-55287be3-68eb-4773-aad6-552432e7a610': 'queued', 'interpolate_to_ssh_grid-2b4a5409-66a8-4834-8175-8da151bbcf52': 'queued', 'interpolate_to_ssh_grid-7eb33475-c4c7-4e63-af7e-d928ab604398': 'queued', 'interpolate_to_ssh_grid-0bc29fc1-a5c6-4f3d-8cba-87ca0a3df48b': 'queued', 'interpolate_to_ssh_grid-af9ff974-b191-4618-88bf-b2b1cf895d6f': 'queued', 'interpolate_to_ssh_grid-4ce9335c-21d7-43a5-a8e3-7a51fdf6d662': 'queued ...
# 2024-03-22 11:23:47,485 - distributed.client - WARNING - Couldn't gather 4414 keys, rescheduling ('interpolate_to_ssh_grid-aa61eccb-a5ed-448c-a56a-f483eb85242f', 'interpolate_to_ssh_grid-8aad92a6-0ef4-45df-9ab8-13fdabc536a1', 'interpolate_to_ssh_grid-7e3efadd-1c3e-4ea8-bc83-1be785fd5bb2', 'interpolate_to_ssh_grid-01569f67-c439-46a7-93b1-b4e4c70bb952', 'interpolate_to_ssh_grid-6f998943-ef6c-4c86-b7b6-85c0673781bc', 'interpolate_to_ssh_grid-333bc81e-745c-4c75-a8da-bbea667e911b', 'interpolate_to_ssh_grid-93e619a4-340b-4826-9127-a71c81ff40f8', 'interpolate_to_ssh_grid-6197ddf6-05ac-4ea8-baff-36fc5e73e7e4', 'interpolate_to_ssh_grid-9b99907a-5f0f-46a0-a3c6-77b25fbe0384', 'interpolate_to_ssh_grid-a0f795dc-c139-41ca-aa19-4abd94023c77', 'interpolate_to_ssh_grid-0c4cd878-1a84-4aed-96c3-0c2088db8d9c', 'interpolate_to_ssh_grid-20e35c2e-7cba-4a45-ae4d-763191bcf86e', 'interpolate_to_ssh_grid-6ee631f7-4402-411b-9755-78a942b885d8', 'interpolate_to_ssh_grid-19d81096-7cfa-4945-abb3-fef8d06045b3', 'interpolate_to_ssh_grid-64625567-835b-4ed3-869c-a6c25c701bf1', 'interpolate_to_ssh_grid-ad15fbfc-8ac7-421d-8e5b-cb1f127c158e', 'interpolate_to_ssh_grid-8b1c0288-1b0e-41ee-a488-139ae9049d77', 'interpolate_to_ssh_grid-43930738-7069-42ef-94e9-d28daed40255', 'interpolate_to_ssh_grid-60ec7b33-dada-4329-be79-e2496759d880', 'interpolate_to_ssh_grid-416ab56f-428a-4038-a3d2-7a3659d4c631', 'interpolate_to_ssh_grid-b3619a60-e011-448d-b28b-c4d0ae3ce917', 'interpolate_to_ssh_grid-3088da0d-d07d-42aa-823c-81bd2aacdd10', 'interpolate_to_ssh_grid-2eb9fcc4-2164-4b31-80fb-83104fac5676', 'interpolate_to_ssh_grid-259fea07-730c-4385-b4df-56733560d5b8', 'interpolate_to_ssh_grid-0a1df719-635c-4e5c-ae4d-38dde1844270', 'interpolate_to_ssh_grid-66938d89-f449-4e6c-a9de-aa6a669473b3', 'interpolate_to_ssh_grid-98a88852-5fa9-4da2-abe3-a2ca2421722b', 'interpolate_to_ssh_grid-986309df-2ab4-427d-94b8-db1869e78154', 'interpolate_to_ssh_grid-27c47bcd-3f1a-4fb0-9333-c157837eb06c', 'interpolate_to_ssh_grid-327ac9c9-c644-4df8-bf96-b1fbe0dfc807', 'interpolate_to_ssh_grid-11a82c8d-a417-4bb0-bd9a-713cb96f563d', 'interpolate_to_ssh_grid-2e06285a-7a36-4322-a9a5-b8d0f9c0723e', 'interpolate_to_ssh_grid-ad1d46e0-90b6-4374-89be-20c0e2f404bb', 'interpolate_to_ssh_grid-07e9223a-fef3-410d-b9f4-c6d252bbacf5', 'interpolate_to_ssh_grid-8869ec7f-3d4e-48f5-9279-50e116831672', 'interpolate_to_ssh_grid-b34397cb-ef5c-4fbd-99c5-545e973ef51a', 'interpolate_to_ssh_grid-22e28576-0498-42a6-b207-7a3945be6525', 'interpolate_to_ssh_grid-aa93a628-d8e9-46f9-9e07-8091a6cba4c3', 'interpolate_to_ssh_grid-5c69b2fe-82b1-4ed2-bdcc-c65fac8149b8', 'interpolate_to_ssh_grid-350dc748-16d4-482f-b7db-1eda7d9851ac', 'interpolate_to_ssh_grid-8dc788ae-3f9f-429e-bea6-681e17b21a31', 'interpolate_to_ssh_grid-355b7152-4f40-4474-8547-418b628d3a45', 'interpolate_to_ssh_grid-75599d35-f2c2-45fe-828b-a8349fa85503', 'interpolate_to_ssh_grid-a1fcd8b8-64c6-4976-ba04-abac49adc76a', 'interpolate_to_ssh_grid-a97dee29-8de9-48cd-abe4-7b98c07d955a', 'interpolate_to_ssh_grid-147e5350-2b12-4bec-838c-752f83502c66', 'interpolate_to_ssh_grid-808d1a83-464a-43b9-8e20-a672db616db4', 'interpolate_to_ssh_grid-55287be3-68eb-4773-aad6-552432e7a610', 'interpolate_to_ssh_grid-2b4a5409-66a8-4834-8175-8da151bbcf52', 'interpolate_to_ssh_grid-7eb33475-c4c7-4e63-af7e-d928ab604398', 'interpolate_to_ssh_grid-0bc29fc1-a5c6-4f3d-8cba-87ca0a3df48b', 'interpolate_to_ssh_grid-af9ff974-b191-4618-88bf-b2b1cf895d6f', 'interpolate_to_ssh_grid-4ce9335c-21d7-43a5-a8e3-7a51fdf6d662', 'interpolate_to_ssh_grid-9b17fcae-4af6-416f-8b31-a20727c2127d', 'interpolate_to_ssh_grid-45ae890d-c9a2-45c8-aa58-84a35891fdbb', 'interpolate_to_ssh_grid-7432a793-967d-4331-838e-d07ad4018be2', 'interpolate_to_ssh_grid-868dfaa6-fde5-4fcb-b8b4-cfd5cb8ba304', 'interpolate_to_ssh_grid-2c3a6a0f-fcc0-4248-a4df-6a121c4c6cf1', 'interpolate_to_ssh_grid-00f29eec-88af-4621-9a16-6793e2300758', 'interpolate_to_ssh_grid-a8facfa5-f38e-4cd1-9589-67dfb7ec1c5d', 'interpolate_to_ssh_grid-8dbb4027-97d6-4e72-9925-cdab75884689' ...
# 2024-03-22 11:23:47,831 - distributed.nanny - WARNING - Restarting worker
# 2024-03-22 11:24:08,536 - distributed.nanny - WARNING - Worker process still alive after 3.199997711181641 seconds, killing

# %% [markdown]
# ### Step 5: Reassemble the Interpolated Data into an xarray Dataset

# %%
# Assuming you want to combine the interpolated results into a new DataArray
# Note: This example might require adjustments for coordinates and dimensions
interpolated_data = xr.concat([xr.DataArray(interpolated_values[i], dims=['y', 'x']) 
                               for i in range(len(interpolated_values))], 
                              dim=dac_cropped_1h.time_counter)

# %%
# Save the interpolated dataset
interpolated_data.to_netcdf("/bettik/PROJECTS/pr-data-ocean/riverama/Datos/DAC_limpio/dac_cropped_1h_SSHgrid_2014.nc")
