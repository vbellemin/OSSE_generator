# %% [markdown]
# ## File to compute the mdt of the balanced motions

# %%
import xarray as xr
import numpy as np 
import glob
#for parallelizing
from joblib import Parallel
from joblib import delayed as jb_delayed

import matplotlib.pyplot as plt

# %% [markdown]
# ## 1) Loading datasets

# %%
ds = xr.open_mfdataset("/bettik/bellemva/ocean_data_challenge/2023e_SSHmapping_HF_Hawaii/dc_ref_eval_coarse/2023e_SSHmapping_HF_Hawaii_eval_2012*.nc")

# %%
ssh_bm = ds.ssh_bm.load()

# %%
mdt = ssh_bm.mean(dim="time")

# %%
mdt.to_netcdf("/bettik/bellemva/ocean_data_challenge/2023e_SSHmapping_HF_Hawaii/mdt.nc")

# %%
plt.figure(figsize=(10,10),dpi=200)
plt.pcolormesh(ssh_bm[61*24,:,:]-mdt.values,cmap='bwr',vmin=-0.2,vmax=0.2)
plt.colorbar()
