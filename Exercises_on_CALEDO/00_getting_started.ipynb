# %%
from datetime import datetime, timedelta

import xarray as xr # to read netcdf files
import numpy as np # to work with arrays
import pandas as pd # to work with dataframes

import matplotlib.pyplot as plt # to plot
import matplotlib # to set plot parameters
import ipympl # to allow interactive plots

pd.set_option('display.max_rows', 20) # maximum number of rows to display

# %%
##################################################
### To have interactive graphs in the notebook ###
# this line must be adapted depending on if using you are using:

# jupyter notebook
# %matplotlib notebook 

# jupyter lab:
#%matplotlib widget

# for external window graphs:
#%matplotlib

# for non-interactive graphs:
#%matplotlib inline

# %% [markdown]
# ## Data and structure

# %%
########################
### Loading the data ###

# to define the path of the file
SSH = '/bettik/PROJECTS/pr-data-ocean/riverama/CALEDO60/CALEDO60-TRPC12NT0_y2014m01d01-d31.1h_SSH.nc' 
data = xr.open_dataset(SSH) # to open the file
data # to show the content of the file
# Out:
# <xarray.Dataset>
# Dimensions:              (y: 853, x: 788, time_counter: 744, axis_nbounds: 2)
# Coordinates:
#     nav_lat              (y, x) float32 ...
#     nav_lon              (y, x) float32 ...
#   * time_counter         (time_counter) datetime64[ns] 2014-01-01T00:30:00 .....
#     time_instant         (time_counter) datetime64[ns] ...
# Dimensions without coordinates: y, x, axis_nbounds
# Data variables:
#     time_counter_bounds  (time_counter, axis_nbounds) datetime64[ns] ...
#     time_instant_bounds  (time_counter, axis_nbounds) datetime64[ns] ...
#     zos                  (time_counter, y, x) float32 ...
# Attributes:
#     name:         1_/scratch/cnt0024/ige2071/brodeau/NEMO/TROPICO12/TROPICO12...
#     description:  ocean T grid variables
#     title:        ocean T grid variables
#     Conventions:  CF-1.6
#     timeStamp:    2021-Jul-30 09:28:08 GMT
#     uuid:         dfea4106-852e-44e9-a456-80ebfbca9f95
# ...

# %%
variable_names = list(data.data_vars) # to get the variable names
print("Variable names (headers):", variable_names) # to print the variable names
# Out:
# Variable names (headers): ['time_counter_bounds', 'time_instant_bounds', 'zos']
